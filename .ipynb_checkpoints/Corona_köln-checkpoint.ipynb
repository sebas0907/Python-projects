# %% [markdown]
# # Analysis of the coronavirus data with Python

# %%
import bs4 
import requests 
from bs4 import BeautifulSoup
import io
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# We need to first get the URL of the official website of the city of Cologne. With help of a the function retrieveData the data is parsed into a list with values starting from the 01.01.2021 until the present day:

# %%
url = "https://www.stadt-koeln.de/artikel/69443/index.html"

# %%
def retrieveData(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")
    data = []
    table = soup.find_all('div', {'class':'tinyblock', 'id':'ziel_0_48'})
    table_body = table[0].find_all('tbody')
    rows = table_body[0].find_all('tr')
    for row in rows:
        cols = row.find_all('td')
        columns = [ele.text.strip() for ele in cols]
        data.append([ele for ele in columns]) # Get rid of empty values #if ele
    data.reverse()
    return data

# %%
#Alternative method
"""
r = requests.get(url)
df_list = pd.read_html(r.text) # this parses all the tables in webpages to a list
df = df_list[0]
df.head()
"""

# %% [markdown]
# Convert the data to dataframe with Pandas and place the very first row as the header any missing values are filled with the mean but some probably need to be removed afterwards depending on the trent:

# %%
data = retrieveData(url)
df = pd.DataFrame(data)

# %%
header = df.iloc[0] 
df = df[1:] 
df.columns = header
df = df.fillna(df.mean())
df.tail(20)
# Out:
# 0         Stand Inzidenzwert Bestätigte Kölner Fälle  \
# 147  27.05.2021         52,4                  52.532
# 148  28.05.2021         51,8                  52.634
# 149  29.05.2021         42,7                  52.681
# 150  30.05.2021         42,2                  52.744
# 151  31.05.2021         40,1                  52.767
# 152  01.06.2021         35,4                  52.766
# 153  02.06.2021         38,1                  52.842
# 154  03.06.2021         38,8                  52.935
# 155  04.06.2021         32,8                  52.961
# 156  05.06.2021         31,1                  52.996
# 157  06.06.2021         27,6                  53.031
# 158  07.06.2021         26,7                  53.051
# 159  08.06.2021         23,7                  53.065
# 160  09.06.2021         18,3                  53.067
# 161  10.06.2021         20,2                  53.155
# 162  11.06.2021         22,3                  53.206
# 163  12.06.2021         22,6                  53.248
# 164  13.06.2021         21,4                  53.266
# 165  14.06.2021         21,3                  53.284
# 166  15.06.2021         20,9                  53.300
#
# 0   Aktuell Infizierte in Köln* Personen in stationärer Behandlung*  \
# 147                       1.277                                 172
# 148                       1.240                                 162
# 149                       1.282                                 154
# 150                       1.104                                 139
# 151                       1.047                                 136
# 152                       1.008                                 128
# 153                         946                                 126
# 154                         794                                 112
# 155                         718                                 112
# 156                         650                                 117
# 157                         598                                 110
# 158                         561                                 107
# 159                         522                                 101
# 160                                                              97
# 161                         511                                  95
# 162                         490                                  97
# 163                         479                                  94
# 164                         437                                  83
# 165                         413                                  80
# 166
#
# 0   Kölner Todesfälle
# 147               699
# 148               700
# 149               702
# 150               702
# 151               702
# 152               705
# 153               707
# 154               709
# 155               709
# 156               709
# 157               710
# 158               711
# 159               712
# 160               712
# 161               713
# 162               714
# 163               715
# 164               717
# 165               717
# 166               717

# %%
#Parse the dates:
df.Stand = pd.to_datetime(df.Stand, dayfirst=True)
df.tail(20)
# Out:
# 0        Stand Inzidenzwert Bestätigte Kölner Fälle  \
# 147 2021-05-27         52,4                  52.532
# 148 2021-05-28         51,8                  52.634
# 149 2021-05-29         42,7                  52.681
# 150 2021-05-30         42,2                  52.744
# 151 2021-05-31         40,1                  52.767
# 152 2021-06-01         35,4                  52.766
# 153 2021-06-02         38,1                  52.842
# 154 2021-06-03         38,8                  52.935
# 155 2021-06-04         32,8                  52.961
# 156 2021-06-05         31,1                  52.996
# 157 2021-06-06         27,6                  53.031
# 158 2021-06-07         26,7                  53.051
# 159 2021-06-08         23,7                  53.065
# 160 2021-06-09         18,3                  53.067
# 161 2021-06-10         20,2                  53.155
# 162 2021-06-11         22,3                  53.206
# 163 2021-06-12         22,6                  53.248
# 164 2021-06-13         21,4                  53.266
# 165 2021-06-14         21,3                  53.284
# 166 2021-06-15         20,9                  53.300
#
# 0   Aktuell Infizierte in Köln* Personen in stationärer Behandlung*  \
# 147                       1.277                                 172
# 148                       1.240                                 162
# 149                       1.282                                 154
# 150                       1.104                                 139
# 151                       1.047                                 136
# 152                       1.008                                 128
# 153                         946                                 126
# 154                         794                                 112
# 155                         718                                 112
# 156                         650                                 117
# 157                         598                                 110
# 158                         561                                 107
# 159                         522                                 101
# 160                                                              97
# 161                         511                                  95
# 162                         490                                  97
# 163                         479                                  94
# 164                         437                                  83
# 165                         413                                  80
# 166
#
# 0   Kölner Todesfälle
# 147               699
# 148               700
# 149               702
# 150               702
# 151               702
# 152               705
# 153               707
# 154               709
# 155               709
# 156               709
# 157               710
# 158               711
# 159               712
# 160               712
# 161               713
# 162               714
# 163               715
# 164               717
# 165               717
# 166               717

# %% [markdown]
# Apparently the data in the website is of string type so we need to do a little processing before we transform the column values to the proper data type

# %%
df['Aktuell Infizierte in Köln*'] = df['Aktuell Infizierte in Köln*'].str.replace('.','')
df['Bestätigte Kölner Fälle'] = df['Bestätigte Kölner Fälle'].str.replace('.','')
df['Inzidenzwert'] = df['Inzidenzwert'].str.replace(',','.')

# %%
df.iloc[:,1:] = df.iloc[:, 1:].apply(pd.to_numeric)

# %%
df.dtypes
# Out:
# 0
# Stand                                  datetime64[ns]
# Inzidenzwert                                  float64
# Bestätigte Kölner Fälle                       float64
# Aktuell Infizierte in Köln*                   float64
# Personen in stationärer Behandlung*           float64
# Kölner Todesfälle                               int64
# dtype: object

# %% [markdown]
# Get the general stats:

# %%
df.describe()
# Out:
# 0      Inzidenzwert  Bestätigte Kölner Fälle  Aktuell Infizierte in Köln*  \
# count    165.000000               164.000000                   163.000000
# mean     103.710909             39610.152439                  1900.325153
# std       50.873360              9040.283199                  1025.063237
# min       18.300000             26017.000000                   413.000000
# 25%       69.700000             32013.000000                  1128.500000
# 50%       93.900000             37417.000000                  1520.000000
# 75%      131.000000             49289.500000                  2442.500000
# max      250.100000             53300.000000                  4362.000000
#
# 0      Personen in stationärer Behandlung*  Kölner Todesfälle
# count                           165.000000         166.000000
# mean                            238.709091         557.698795
# std                              80.157544         108.511553
# min                              80.000000         343.000000
# 25%                             174.000000         473.750000
# 50%                             235.000000         566.000000
# 75%                             292.000000         647.500000
# max                             398.000000         717.000000

# %% [markdown]
# It will be useful to start another dataframe that has the dates as the index and gets rid of the missing values. In some other cases where a relevant value such as the number infected individuals is missing, it is a better practice to fill it with the latest report.

# %%
dff = df.set_index(['Stand'])
dff.fillna(method='ffill',inplace=True)
#dff = dff.dropna()
dff.tail(10)
# Out:
# 0           Inzidenzwert  Bestätigte Kölner Fälle  \
# Stand
# 2021-06-06          27.6                  53031.0
# 2021-06-07          26.7                  53051.0
# 2021-06-08          23.7                  53065.0
# 2021-06-09          18.3                  53067.0
# 2021-06-10          20.2                  53155.0
# 2021-06-11          22.3                  53206.0
# 2021-06-12          22.6                  53248.0
# 2021-06-13          21.4                  53266.0
# 2021-06-14          21.3                  53284.0
# 2021-06-15          20.9                  53300.0
#
# 0           Aktuell Infizierte in Köln*  Personen in stationärer Behandlung*  \
# Stand
# 2021-06-06                        598.0                                110.0
# 2021-06-07                        561.0                                107.0
# 2021-06-08                        522.0                                101.0
# 2021-06-09                        522.0                                 97.0
# 2021-06-10                        511.0                                 95.0
# 2021-06-11                        490.0                                 97.0
# 2021-06-12                        479.0                                 94.0
# 2021-06-13                        437.0                                 83.0
# 2021-06-14                        413.0                                 80.0
# 2021-06-15                        413.0                                 80.0
#
# 0           Kölner Todesfälle
# Stand
# 2021-06-06                710
# 2021-06-07                711
# 2021-06-08                712
# 2021-06-09                712
# 2021-06-10                713
# 2021-06-11                714
# 2021-06-12                715
# 2021-06-13                717
# 2021-06-14                717
# 2021-06-15                717

# %% [markdown]
# Let's plot the cumulative confirmed cases and the number of infected individuals:

# %%
dff.plot(y='Bestätigte Kölner Fälle')
dff.plot(y=dff.columns[2])
dff.plot(y=dff.columns[0])

# %% [markdown]
# The number of hospitalized individuals and deseased ones can be appreciated as well

# %%
dff.columns.name = 'Legend'

# %%
dff.plot(y=[dff.columns[3],dff.columns[-1]])

# %% [markdown]
# As complementary information we can extract the dayly confirmed cases also

# %%
df_new = dff['Bestätigte Kölner Fälle'].diff().dropna().to_frame()
df_new.tail()
# Out:
#             Bestätigte Kölner Fälle
# Stand
# 2021-06-11                     51.0
# 2021-06-12                     42.0
# 2021-06-13                     18.0
# 2021-06-14                     18.0
# 2021-06-15                     16.0

# %%
#new.columns = ['date','New infections']

# %%
df_new.reset_index(inplace=True)
df_new.columns = ['date','dayly infections']
df_new.plot.scatter(x='date', y='dayly infections')

# %%
df_new.boxplot()

# %%
# number of new infections:
I = df_new[df_new['dayly infections']<400]

# %%
I.plot.scatter(x='date', y='dayly infections')

# %%
#N = I['dayly infections'].values
Nc = df_new['dayly infections'].values

# %%
#x = np.arange(len(N))
xc = np.arange(len(Nc))

# %%
from scipy.optimize import curve_fit

def exponential(x, a, b):
    return a*np.exp(b*x)

def power(x, a, b, c):
    return a*(b**(c*x))

def expo(x,a,b,c):
    return a*np.exp(b*x)+c

def powo(x,a,b,c,d):
    return a*(b**(c*x))+d

# %%
pars, cov = curve_fit(f=expo, xdata=xc[110:], ydata=Nc[110:], p0=[10, -.1, .2])
# Out:
# C:\Users\sebas\anaconda3\envs\intel\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: overflow encountered in exp
#   # Remove the CWD from sys.path while we load stuff.

# %%
plt.plot(xc[110:], expo(xc[110:], *pars))
plt.plot(xc, Nc,'.')

# %%
a, b, c = pars

# %%
Xc = np.arange(len(xc),200)
curve = expo(Xc,a,b,c)
plt.plot(Xc,curve)
plt.grid()
plt.show()

# %% [markdown]
# Let's do some machine learning

# %% [markdown]
# ## Machine Learning Models of Linear Regression

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
X = xc.reshape(1,-1).astype('float')
y = Nc.reshape(1,-1).astype('float')

# %%
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X)

# %%
plt.plot(X.flatten(),y.flatten(),'.')
plt.plot(X.flatten(),y_pred.flatten())
plt.show()

# %% [markdown]
# We can see from the graphic that not only the model is inapropriate but it leads to overfitting. To overcome that we must resort to polynomial regression. Notice that there is no reason to prefer a polyonmial degree over the other since ultimately it is the SIR model that dictates how the proper parameters behave according to the theory. This might only be taken as a proxy for forecasting:

# %%
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
# generate points used to plot
x_plot = xc
# create matrix versions of these arrays
X = xc[:, np.newaxis]
X_plot = x_plot[:, np.newaxis]
y = Nc[:,np.newaxis]

colors = ['teal', 'yellowgreen', 'red', 'gold']
lw = 2

plt.figure(figsize=(16,10))
plt.plot(x_plot, y, color='cornflowerblue', linewidth=lw, label="ground truth")
plt.scatter(xc, y, color='navy', s=30, marker='o', label="training points")


for count, degree in enumerate([3, 4, 5, 6]):
    model = make_pipeline(PolynomialFeatures(degree), Ridge())
    model.fit(X, y)
    y_plot = model.predict(X_plot)
    plt.plot(x_plot, y_plot, color=colors[count], linewidth=lw,
             label="degree %d" % degree)

plt.legend(loc='lower left')
plt.grid()
plt.show()
# Out:
# C:\Users\sebas\anaconda3\envs\intel\lib\site-packages\sklearn\linear_model\_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.5816e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\sebas\anaconda3\envs\intel\lib\site-packages\sklearn\linear_model\_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=6.58632e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\sebas\anaconda3\envs\intel\lib\site-packages\sklearn\linear_model\_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.7198e-28): result may not be accurate.
#   overwrite_a=True).T

# %%
x_preds = np.arange(len(Nc),len(Nc)+20) #let's say 20 days
X_preds = x_preds[:, np.newaxis]
y_preds = model.predict(X_preds)

# %%
print(y_preds.flatten())
# Out:
# [  90.7599074   111.64646116  135.53215642  162.60404961  193.05590088
#   227.08831032  264.90885554  306.73223031  352.78038457  403.2826656
#   458.47596046  518.60483965  583.921702    654.68692079  731.16899115
#   813.64467862  902.39916899  997.72621938 1099.92831052 1209.31680031]

# %% [markdown]
# ## Time Series Forecasting with TensorFlow:

# %% [markdown]
# Well, the resulting values don't really make sense given that the number of infections should be always positive. But of course we already knew that, the epidemic and postepidemic phases are always exponential.
# For the sake of completeness, let us try a very basic forecasting model with neural networks:

# %%
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler

# %%
def arrange_data(data, days):
    days_before_values = []
    days_values = []
    
    for i in range(len(data)- days):
        days_before_values.append(data[i:(i+days)])
        days_values.append(data[i+days])
    
    return np.array(days_before_values), np.array(days_values)

# %%
#moving average of three days for the number of infected individuals:
NSMA=dff.Inzidenzwert.values.reshape(-1,1)
SMA=dff[dff.columns[0]].rolling(7, min_periods=1).mean()

# %%
normal_data = dff.Inzidenzwert.values.reshape(-1,1)
mc = MinMaxScaler(feature_range=(0,1))
final_normal_data = mc.fit_transform(normal_data)

# %%
initial_data = SMA.values.reshape(-1,1)
sc = MinMaxScaler(feature_range=(0,1))
final_data = sc.fit_transform(initial_data)

# %%
DAYS_BEFORE = 7
days_before_values, days_values = arrange_data(final_data, DAYS_BEFORE)
days_before_values = days_before_values.reshape((days_before_values.shape[0], DAYS_BEFORE, 1))

Xs = days_before_values
ys = days_values

# %%
_,Ys = arrange_data(final_normal_data, DAYS_BEFORE)

# %%
model = Sequential()
model.add(LSTM(30, input_shape=(DAYS_BEFORE,1)))
model.add(Dense(10, activation='relu'))
model.add(Dense(1))
optimizer = tf.keras.optimizers.RMSprop()
model.compile(loss = 'mse', optimizer = 'adam', metrics = ['mae']) #SGD

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30)                3840
# _________________________________________________________________
# dense (Dense)                (None, 10)                310
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 4,161
# Trainable params: 4,161
# Non-trainable params: 0
# _________________________________________________________________

# %%
ES = tf.keras.callbacks.EarlyStopping(monitor='mae', patience=5)
history = model.fit(Xs, ys, epochs = 500, batch_size=64,callbacks=[ES])
# Out:
# Train on 159 samples
# Epoch 1/500
# 159/159 [==============================] - 4s 25ms/sample - loss: 0.2315 - mae: 0.4141
# Epoch 2/500
# 159/159 [==============================] - 0s 351us/sample - loss: 0.1793 - mae: 0.3591
# Epoch 3/500
# 159/159 [==============================] - 0s 263us/sample - loss: 0.1460 - mae: 0.3226
# Epoch 4/500
# 159/159 [==============================] - 0s 276us/sample - loss: 0.1233 - mae: 0.2946
# Epoch 5/500
# 159/159 [==============================] - 0s 226us/sample - loss: 0.1039 - mae: 0.2674
# Epoch 6/500
# 159/159 [==============================] - 0s 251us/sample - loss: 0.0850 - mae: 0.2385
# Epoch 7/500
# 159/159 [==============================] - 0s 245us/sample - loss: 0.0679 - mae: 0.2092
# Epoch 8/500
# 159/159 [==============================] - 0s 226us/sample - loss: 0.0521 - mae: 0.1794
# Epoch 9/500
# 159/159 [==============================] - 0s 213us/sample - loss: 0.0382 - mae: 0.1484
# Epoch 10/500
# 159/159 [==============================] - 0s 220us/sample - loss: 0.0269 - mae: 0.1183
# Epoch 11/500
# 159/159 [==============================] - 0s 289us/sample - loss: 0.0171 - mae: 0.0937
# Epoch 12/500
# 159/159 [==============================] - 0s 232us/sample - loss: 0.0120 - mae: 0.0841
# Epoch 13/500
# 159/159 [==============================] - 0s 276us/sample - loss: 0.0108 - mae: 0.0830
# Epoch 14/500
# 159/159 [==============================] - 0s 276us/sample - loss: 0.0121 - mae: 0.0912
# Epoch 15/500
# 159/159 [==============================] - 0s 245us/sample - loss: 0.0130 - mae: 0.0990
# Epoch 16/500
# 159/159 [==============================] - 0s 257us/sample - loss: 0.0126 - mae: 0.0971
# 159/159 [==============================] - 0s 232us/sample - loss: 4.7259e-04 - mae: 0.0171
# Epoch 248/500
# 159/159 [==============================] - 0s 213us/sample - loss: 4.9385e-04 - mae: 0.0175

# %%
X_test = Xs[-1]
X_test = np.expand_dims(X_test, axis=0)

# %%
Xs_pred = final_data[-DAYS_BEFORE:]
Xs_pred = np.expand_dims(Xs_pred, axis=0)

# %%
prediction = sc.inverse_transform(model.predict(X_test)).flatten()[0]
ys_pred = sc.inverse_transform(model.predict(Xs_pred)).flatten()[0]
predictions_on_training = sc.inverse_transform(model.predict(Xs))

# %%
print('predicted value: ', np.round(prediction,2))
print('actual value: ', SMA[-1])
print('prediction for tomorrow: ', np.round(ys_pred,2))
# Out:
# predicted value:  23.18
# actual value:  20.999999999999876
# prediction for tomorrow:  23.18

# %%
plt.figure(figsize = (15,10))
plt.plot(len(initial_data),prediction, 'o', color='red')
plt.plot(len(initial_data)+1,ys_pred, 'o', color='blue')
plt.plot(initial_data, color = 'gray')
plt.plot(DAYS_BEFORE-1+np.arange(len(predictions_on_training)), predictions_on_training, color = 'green', dashes = [6,2])
plt.xlabel('Days')
plt.ylabel('Incidence seven days SMA')
plt.grid()
plt.show()

# %% [markdown]
# We've got actually nice results!
# The basic RNN is able to force predictions based on a three day seasonal window. Whether that can be extended for longer periods of time depends crucially upon many factors since we are not talking about the weather but a virus!
#
# Having explored the less regular options now we can move to actual biology: the SIR-D model.

# %% [markdown]
# ## Modelling the Coronavirus Spread with the SIRD Model

# %%
dff.tail()
# Out:
# Legend      Inzidenzwert  Bestätigte Kölner Fälle  \
# Stand
# 2021-06-11          22.3                  53206.0
# 2021-06-12          22.6                  53248.0
# 2021-06-13          21.4                  53266.0
# 2021-06-14          21.3                  53284.0
# 2021-06-15          20.9                  53300.0
#
# Legend      Aktuell Infizierte in Köln*  Personen in stationärer Behandlung*  \
# Stand
# 2021-06-11                        490.0                                 97.0
# 2021-06-12                        479.0                                 94.0
# 2021-06-13                        437.0                                 83.0
# 2021-06-14                        413.0                                 80.0
# 2021-06-15                        413.0                                 80.0
#
# Legend      Kölner Todesfälle
# Stand
# 2021-06-11                714
# 2021-06-12                715
# 2021-06-13                717
# 2021-06-14                717
# 2021-06-15                717

# %%
N = 1e6
It=dff[dff.columns[2]]/N
#Rt=dff[dff.columns[4]]/N
Rt=(dff[dff.columns[1]]-dff[dff.columns[4]])/N
Dt=dff[dff.columns[4]]/N
St=1-It-Rt-Dt

# %%
Cases=dff[dff.columns[1]]/N

# %%
S0=1-It[0]-Rt[0]-Dt[0]

# %%
St.plot()

# %%
It.plot()

# %%
Rt.plot()

# %%
Dt.plot()

# %%
it = It.copy().values
#itm = np.sort(it) #second smallest value

# %%
idxb=list(np.where(it==it.max()))[0][0]
#idxa=list(np.where(it==it.min()))[0]
#idxb=list(np.where(it==it.max()))[0]

# %%
idxa=list(np.where(it==it[:idxb].min()))[0][0]

# %%
ST=St[idxa:]
IT=It[idxa:]
RT=Rt[idxa:]
DT=Dt[idxa:]
CT=Cases[idxa:]

# %%
ST.plot()

# %%
IT.plot()

# %%
RT.plot()

# %%
DT.plot()

# %%
CT.plot()

# %%
XI =It[idxa:idxb-10].values
XD = Dt[idxa:idxb-10].values
XR = Rt[idxa:idxb-10].values

# %%
#plt.plot(np.arange(len(XI)),XI)
plt.plot(np.arange(len(XR)),XR)
plt.grid()
plt.show()

# %%
pars, cov = curve_fit(f=exponential, xdata=np.arange(len(XI)), ydata=XI, p0=[XI[0], .1])
pars2, cov2 = curve_fit(f=power, xdata=np.arange(len(XI)), ydata=XI, p0=[XI[0], 1, .1])
pars3, cov3 = curve_fit(f=expo, xdata=np.arange(len(XR)), ydata=XR, p0=[XR[0], .1, .03])

# %%
a1, b1 = pars
a2,b2,c2 = pars2
a3,b3,c3 = pars3

# %%
plt.plot(np.arange(len(XI)),exponential(np.arange(len(XI)),*pars))
plt.plot(np.arange(len(XI)),power(np.arange(len(XI)),*pars2))
plt.plot(np.arange(len(XI)),XI,'.')
plt.grid()
plt.show()

# %%
plt.plot(np.arange(len(XR)),expo(np.arange(len(XR)),*pars3))
plt.plot(np.arange(len(XR)),XR,'.')
plt.grid()
plt.show()

# %%
R0=np.exp(b/c2) #basic reproduction number

# %%
#alpha = 1/11
#mu = (DT[0]/CT[0])
#beta = R0*alpha

# %%
d = 69
mu = b1*((DT[d]-DT[0])/(IT[d]-IT[0])) #death rate
alpha = b1*((RT[d]-RT[0])/(IT[d]-IT[0])) #recovery rate
beta =(b1+alpha+mu)/ST[0] #rate of infection
R_0=beta/alpha #basic reproduction number according to SIR

# %%
print('R value: ',R_0)
# Out:
# R value:  1.293262150005115

# %% [markdown]
# Having already estimated the relevant parameters, we can now turn to the SIR model

# %%
from scipy.integrate import odeint
# Initial number of infected and recovered individuals, I0 and R0. 
#Contact rate, beta, and mean recovery rate, gamma, (in 1/days).

IT0, RT0, ST0, DT0 = IT[0], RT[0], ST[0], DT[0]
# A grid of time points (in days)
t = np.arange(len(IT)+300)

# The SIR model differential equations.
def deriv(y, t, beta, alpha, mu):
    S, I, R, D = y
    dSdt = -beta * S * I 
    dIdt = beta * S * I - alpha * I - mu * I
    dRdt = alpha * I
    dDdt = mu * I
    return dSdt, dIdt, dRdt, dDdt

# Initial conditions vector
y0 = ST0, IT0, RT0, DT0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(beta, alpha, mu))
S, I, R, D = ret.T

# Plot the data on three separate curves for S(t), I(t) and R(t)
fig = plt.figure(facecolor='w',figsize=(15,10))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.plot(t, S, 'b', alpha=0.5, lw=2, label='Susceptible')
ax.plot(t, I, 'r', alpha=0.5, lw=2, label='Infected')
ax.plot(t, R, 'g', alpha=0.5, lw=2, label='Recovered with immunity')
ax.plot(t, D, 'black', alpha=0.5, lw=2, label='Deseased')
ax.plot(np.arange(len(IT)),IT.values,'--')
ax.plot(np.arange(len(DT)),DT.values,'--')
ax.plot(np.arange(len(RT)),RT.values,'--')
ax.plot(np.arange(len(ST)),ST.values,'--')
ax.set_xlabel('Time /days')
ax.set_ylabel('Number (Mios)')
ax.set_xlim(0,len(t))
ax.set_ylim(0,1/50)
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %%
#side remarks:
# the initial number of removed individuals is equal to the number of confirmed cases minus the deseased ones.

# %%
df[df[df.columns[3]]==df[df.columns[3]].max()]
# Out:
# 0        Stand  Inzidenzwert  Bestätigte Kölner Fälle  \
# 117 2021-04-27         240.0                  46991.0
#
# 0    Aktuell Infizierte in Köln*  Personen in stationärer Behandlung*  \
# 117                       4362.0                                386.0
#
# 0    Kölner Todesfälle
# 117                629

# %% [markdown]
# Now at last we can have a look a the actual development of the epidemic. An exponential fit would be enough to show the relevant values such as the R-value:

# %%
X_decay = It[idxb+7:].values*N
plt.plot(np.arange(len(X_decay)),X_decay,'.',color='r')
plt.xlabel('days')
plt.ylabel('infected')
plt.grid()
plt.show()

# %%
parameters, covariance = curve_fit(f=exponential, xdata=np.arange(len(X_decay)), ydata=X_decay, p0=[X_decay[0], -.1])
parameters_, covariance_ = curve_fit(f=power, xdata=np.arange(len(X_decay)), ydata=X_decay, p0=[X_decay[0], 0.66, 0.1])
# Out:
# C:\Users\sebas\anaconda3\envs\intel\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in power
#   import sys

# %%
A, K = parameters
B, R, F = parameters_

# %%
plt.plot(np.arange(len(X_decay)+50),exponential(np.arange(len(X_decay)+50),*parameters))
plt.plot(np.arange(len(X_decay)+50),power(np.arange(len(X_decay)+50),*parameters_))
plt.plot(np.arange(len(X_decay)),X_decay,'.',color='r')
plt.xlabel('days')
plt.ylabel('infected')
plt.grid()
plt.show()

# %%
# R-value:
R0=np.exp(K/F)
print("Basic reproduction number R: ",np.round(R,2))
# Out:
# Basic reproduction number R:  0.57

# %%
# Serial number T_G:
T_G = 1/F
print('Serial number T_G: {:.2f} days'.format(T_G))
# Out:
# Serial number T_G: 10.75 days

# %%
# (doubling time) Verdopplungszeit
td = -np.log(2)/K
print('Doubling time td: {:.2f} days'.format(td))
# Out:
# Doubling time td: 13.19 days

# %%
print('Decay constant K: {:.2f} /days '.format(K))
# Out:
# Decay constant K: -0.05 /days

# %%
print('Most recent value from best fit: {} infected individuals'.format(int(power(len(X_decay),*parameters_))))
print('Most recent value from data: {} infected individuals'.format(int(X_decay[-1])))
# Out:
# Most recent value from best fit: 446 infected individuals
# Most recent value from data: 413 infected individuals

# %%
perr = np.sqrt(np.diag(covariance))
print('Error in amplitude: {:.2f} infected'.format(perr[0]))
print('Error in decay constant: {:0.2e} /days'.format(perr[1]))
# Out:
# Error in amplitude: 59.01 infected
# Error in decay constant: 1.15e-03 /days
